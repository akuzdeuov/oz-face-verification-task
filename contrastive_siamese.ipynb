# %%
from losses.losses import ContrastiveLoss
from dataset.datasets import SiameseNetworkDataset
from models.nn import ContrastiveSiameseNetwork

from PIL import Image
import numpy as np
import plot
import time

import torchvision.transforms as transforms
import torchvision.datasets as datasets
import torchvision.utils
import torchvision

from torch.utils.data import DataLoader
from torch import optim
import torch

# %%
# define paths to the training and val sets
TRAIN_DATA_PATH = "./casia_webface/train/"
VAL_DATA_PATH = "./casia_webface/val/"

# define training parameters
EPOCHS = 5
BATCH_SIZE = 128
NUM_WORKERS = 32
IMG_SIZE = 32
LR = 0.001

# %%
# training dataset image folder
train_image_folder = datasets.ImageFolder(root=TRAIN_DATA_PATH)
# apply transformation to the training set
train_transforms = transforms.Compose([transforms.Resize((IMG_SIZE,IMG_SIZE)),
                                       transforms.RandomHorizontalFlip(),
                                       transforms.ToTensor()])
# initialize train dataset
train_dataset = SiameseNetworkDataset(imageFolder=train_image_folder,
                                      transform=train_transforms)


# valiation dataset image folder
val_image_folder = datasets.ImageFolder(root=VAL_DATA_PATH)
# apply transformation to the valiation set
val_transforms = transforms.Compose([transforms.Resize((IMG_SIZE,IMG_SIZE)),
                                     transforms.ToTensor()])
# initialize valiation dataset
val_dataset = SiameseNetworkDataset(imageFolder=val_image_folder,
                                    transform=val_transforms)
# validation dataloader
val_dataloader = DataLoader(val_dataset, batch_size=BATCH_SIZE)

# %%
# a simple dataloader for visualization
vis_dataloader = DataLoader(val_dataset, batch_size=8)

# extract one batch
example_batch = next(iter(vis_dataloader))

# example batch is a list containing 2x8 images, indexes 0 (neg) and 1 (pos)
concatenated = torch.cat((example_batch[0], example_batch[1]),0)

plot.imshow(torchvision.utils.make_grid(concatenated))
print(example_batch[2].numpy().reshape(-1))
# Out:
# [1. 1. 0. 1. 1. 1. 1. 0.]

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print("Device:", device)
# Out:
# Device: cuda

# %%
net = ContrastiveSiameseNetwork().to(device)
print(net)

criterion = ContrastiveLoss()
optimizer = optim.Adam(net.parameters(), lr=LR)
# Out:
# ContrastiveSiameseNetwork(
#   (resnet): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (7): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (8): AdaptiveAvgPool2d(output_size=(1, 1))
#   )
#   (fc): Linear(in_features=512, out_features=128, bias=True)
# )

# %%
def train(model, device, train_loader, optimizer, criterion, epoch, log_interval, train_loss):
    model.train()

    for batch_idx, (images_1, images_2, targets) in enumerate(train_loader):
        images_1, images_2, targets = images_1.to(device), images_2.to(device), targets.to(device)
        optimizer.zero_grad()
        output1, output2 = model(images_1, images_2)
        loss = criterion(output1, output2, targets)
        train_loss += loss.item()
        loss.backward()
        optimizer.step()
        if batch_idx % log_interval == 0:
            print('epoch: {} ({:.0f}%) \trunning_loss: {:.4f}'.format(
                epoch, 100. * batch_idx / len(train_loader), loss.item()))
            
    train_loss /= len(train_loader)
    return train_loss

def test(model, device, criterion, test_loader):
    model.eval()
    test_loss = 0

    with torch.no_grad():
        for (images_1, images_2, targets) in test_loader:
            images_1, images_2, targets = images_1.to(device), images_2.to(device), targets.to(device)
            output1, output2 = model(images_1, images_2)
            loss = criterion(output1, output2, targets)
            test_loss += loss.item()

    test_loss /= len(test_loader)
    return test_loss

# %%
train_losses = []
val_losses = []
log_interval = 100

# start training
for epoch in range(EPOCHS):
    start_time = time.time()
    train_loss = 0
    # training dataloader is initialized for each epoch
    # such that new positive and negative pairs are created
    train_dataloader = DataLoader(train_dataset,
                                  num_workers=NUM_WORKERS,
                                  batch_size=BATCH_SIZE)
    
    train_loss = train(net, device, train_dataloader, optimizer, criterion, epoch, log_interval, train_loss)
    val_loss = test(net, device, criterion, val_dataloader)
    train_losses.append(train_loss)
    val_losses.append(val_loss)
    end_time = time.time()
    print("\n[INFO] epoch: {} | time_per_epoch: {:.2f} sec | avg_train_loss: {:.4f} | avg_val_loss: {:.4f}\n".format(epoch, end_time-start_time, train_loss, val_loss))
# Out:
# epoch: 0 (0%) 	running_loss: 233.4404
# epoch: 0 (3%) 	running_loss: 0.2739
# epoch: 0 (5%) 	running_loss: 0.2795
# epoch: 0 (8%) 	running_loss: 0.2841
# epoch: 0 (11%) 	running_loss: 0.2752
# epoch: 0 (13%) 	running_loss: 0.2727
# epoch: 0 (16%) 	running_loss: 0.2516
# epoch: 0 (19%) 	running_loss: 0.3143
# epoch: 0 (22%) 	running_loss: 0.3456
# epoch: 0 (24%) 	running_loss: 0.3841
# epoch: 0 (27%) 	running_loss: 0.2980
# epoch: 0 (30%) 	running_loss: 0.2505
# epoch: 0 (32%) 	running_loss: 0.2837
# epoch: 0 (35%) 	running_loss: 0.3877
# epoch: 0 (38%) 	running_loss: 0.3580
# epoch: 0 (40%) 	running_loss: 0.2772
# epoch: 0 (43%) 	running_loss: 0.2678
# epoch: 0 (46%) 	running_loss: 0.2428
# epoch: 0 (49%) 	running_loss: 0.2704
# epoch: 0 (51%) 	running_loss: 0.2639
# epoch: 0 (54%) 	running_loss: 0.2576
# epoch: 0 (57%) 	running_loss: 0.2932
# epoch: 0 (59%) 	running_loss: 0.5300
# epoch: 0 (62%) 	running_loss: 0.3467
# epoch: 0 (65%) 	running_loss: 0.2637
# epoch: 0 (67%) 	running_loss: 0.2517
# epoch: 0 (70%) 	running_loss: 0.3090
# epoch: 0 (73%) 	running_loss: 0.2605
# epoch: 0 (75%) 	running_loss: 0.3115
# epoch: 0 (78%) 	running_loss: 0.2585
# epoch: 0 (81%) 	running_loss: 0.2652
# epoch: 0 (84%) 	running_loss: 0.2755
# epoch: 0 (86%) 	running_loss: 0.2775
# epoch: 0 (89%) 	running_loss: 0.2671
# epoch: 0 (92%) 	running_loss: 0.2589
# epoch: 0 (94%) 	running_loss: 0.2718
# epoch: 0 (97%) 	running_loss: 0.3997
# epoch: 0 (100%) 	running_loss: 0.2794
#
# [INFO] epoch: 0 | time_per_epoch: 88.18 sec | avg_train_loss: 0.6389 | avg_val_loss: 0.2877
#
# epoch: 1 (0%) 	running_loss: 0.2618
# epoch: 1 (3%) 	running_loss: 0.2745
# epoch: 1 (5%) 	running_loss: 0.3507
# epoch: 1 (8%) 	running_loss: 0.2679
# epoch: 1 (11%) 	running_loss: 0.2671
# epoch: 1 (13%) 	running_loss: 0.2647
# epoch: 1 (16%) 	running_loss: 0.2835
# epoch: 1 (19%) 	running_loss: 0.2807
# epoch: 1 (22%) 	running_loss: 0.2631
# epoch: 1 (24%) 	running_loss: 0.2840
# epoch: 1 (27%) 	running_loss: 0.3214
# epoch: 1 (30%) 	running_loss: 0.2746
# epoch: 1 (32%) 	running_loss: 0.3339
# epoch: 1 (35%) 	running_loss: 0.2519
# epoch: 1 (38%) 	running_loss: 0.2776
# epoch: 1 (40%) 	running_loss: 0.2786
# epoch: 1 (43%) 	running_loss: 0.2934
# epoch: 1 (46%) 	running_loss: 0.2944
# epoch: 1 (49%) 	running_loss: 0.3010
# epoch: 1 (51%) 	running_loss: 0.3045
# epoch: 1 (54%) 	running_loss: 0.3114
# epoch: 1 (57%) 	running_loss: 0.2885
# epoch: 1 (59%) 	running_loss: 0.4199
# epoch: 1 (62%) 	running_loss: 0.3139
# epoch: 1 (65%) 	running_loss: 0.3323
# epoch: 1 (67%) 	running_loss: 0.4002
# epoch: 1 (70%) 	running_loss: 0.3578
# epoch: 1 (73%) 	running_loss: 0.2569
# epoch: 1 (75%) 	running_loss: 0.2547
# epoch: 1 (78%) 	running_loss: 0.2564
# epoch: 1 (81%) 	running_loss: 0.2606
# epoch: 1 (84%) 	running_loss: 0.3271
# epoch: 1 (86%) 	running_loss: 0.2795
# epoch: 1 (89%) 	running_loss: 0.3266
# epoch: 1 (92%) 	running_loss: 0.3767
# epoch: 1 (94%) 	running_loss: 0.3167
# epoch: 1 (97%) 	running_loss: 0.2858
# epoch: 1 (100%) 	running_loss: 0.2671
#
# [INFO] epoch: 1 | time_per_epoch: 87.61 sec | avg_train_loss: 0.3011 | avg_val_loss: 0.3029
#
# epoch: 2 (0%) 	running_loss: 0.2657
# epoch: 2 (3%) 	running_loss: 0.2840
# epoch: 2 (5%) 	running_loss: 0.2760
# epoch: 2 (8%) 	running_loss: 0.2831
# epoch: 2 (11%) 	running_loss: 0.2577
# epoch: 2 (13%) 	running_loss: 0.2617
# epoch: 2 (16%) 	running_loss: 0.2766
# epoch: 2 (19%) 	running_loss: 0.2737
# epoch: 2 (22%) 	running_loss: 0.2817
# epoch: 2 (24%) 	running_loss: 0.3020
# epoch: 2 (27%) 	running_loss: 0.3059
# epoch: 2 (30%) 	running_loss: 0.5624
# epoch: 2 (32%) 	running_loss: 0.2768
# epoch: 2 (35%) 	running_loss: 0.3175
# epoch: 2 (38%) 	running_loss: 0.2570
# epoch: 2 (40%) 	running_loss: 0.2943
# epoch: 2 (43%) 	running_loss: 0.2704
# epoch: 2 (46%) 	running_loss: 0.3081
# epoch: 2 (49%) 	running_loss: 0.2990
# epoch: 2 (51%) 	running_loss: 0.3362
# epoch: 2 (54%) 	running_loss: 0.2676
# epoch: 2 (57%) 	running_loss: 0.2997
# epoch: 2 (59%) 	running_loss: 0.3525
# epoch: 2 (62%) 	running_loss: 0.2988
# epoch: 2 (65%) 	running_loss: 0.2766
# epoch: 2 (67%) 	running_loss: 0.2752
# epoch: 2 (70%) 	running_loss: 0.2999
# epoch: 2 (73%) 	running_loss: 0.3141
# epoch: 2 (75%) 	running_loss: 0.2403
# epoch: 2 (78%) 	running_loss: 0.2810
# epoch: 2 (81%) 	running_loss: 0.2704
# epoch: 2 (84%) 	running_loss: 0.2790
# epoch: 2 (86%) 	running_loss: 0.3013
# epoch: 2 (89%) 	running_loss: 0.2753
# epoch: 2 (92%) 	running_loss: 0.2835
# epoch: 2 (94%) 	running_loss: 0.2964
# epoch: 2 (97%) 	running_loss: 0.2977
# epoch: 2 (100%) 	running_loss: 0.2946
#
# [INFO] epoch: 2 | time_per_epoch: 88.78 sec | avg_train_loss: 0.2945 | avg_val_loss: 0.3205
#
# epoch: 3 (0%) 	running_loss: 0.2869
# epoch: 3 (3%) 	running_loss: 0.2531
# epoch: 3 (5%) 	running_loss: 0.5396
# epoch: 3 (8%) 	running_loss: 0.2712
# epoch: 3 (11%) 	running_loss: 0.2826
# epoch: 3 (13%) 	running_loss: 0.2402
# epoch: 3 (16%) 	running_loss: 0.2688
# epoch: 3 (19%) 	running_loss: 0.2710
# epoch: 3 (22%) 	running_loss: 0.2905
# epoch: 3 (24%) 	running_loss: 0.3160
# epoch: 3 (27%) 	running_loss: 0.2869
# epoch: 3 (30%) 	running_loss: 0.2969
# epoch: 3 (32%) 	running_loss: 0.2826
# epoch: 3 (35%) 	running_loss: 0.2623
# epoch: 3 (38%) 	running_loss: 0.3047
# epoch: 3 (40%) 	running_loss: 0.2712
# epoch: 3 (43%) 	running_loss: 0.2690
# epoch: 3 (46%) 	running_loss: 0.2552
# epoch: 3 (49%) 	running_loss: 0.2742
# epoch: 3 (51%) 	running_loss: 0.2596
# epoch: 3 (54%) 	running_loss: 0.2867
# epoch: 3 (57%) 	running_loss: 0.2803
# epoch: 3 (59%) 	running_loss: 0.2644
# epoch: 3 (62%) 	running_loss: 0.3528
# epoch: 3 (65%) 	running_loss: 0.2705
# epoch: 3 (67%) 	running_loss: 0.2608
# epoch: 3 (70%) 	running_loss: 0.2617
# epoch: 3 (73%) 	running_loss: 0.3137
# epoch: 3 (75%) 	running_loss: 0.2927
# epoch: 3 (78%) 	running_loss: 0.2692
# epoch: 3 (81%) 	running_loss: 0.3002
# epoch: 3 (84%) 	running_loss: 0.3777
# epoch: 3 (86%) 	running_loss: 0.2737
# epoch: 3 (89%) 	running_loss: 0.2712
# epoch: 3 (92%) 	running_loss: 0.2421
# epoch: 3 (94%) 	running_loss: 0.2652
# epoch: 3 (97%) 	running_loss: 0.2688
# epoch: 3 (100%) 	running_loss: 0.2423
#
# [INFO] epoch: 3 | time_per_epoch: 87.28 sec | avg_train_loss: 0.2841 | avg_val_loss: 0.2996
#
# epoch: 4 (0%) 	running_loss: 0.2926
# epoch: 4 (3%) 	running_loss: 0.2809
# epoch: 4 (5%) 	running_loss: 0.2676
# epoch: 4 (8%) 	running_loss: 0.3297
# epoch: 4 (11%) 	running_loss: 0.2747
# epoch: 4 (13%) 	running_loss: 0.2644
# epoch: 4 (16%) 	running_loss: 0.2608
# epoch: 4 (19%) 	running_loss: 0.2693
# epoch: 4 (22%) 	running_loss: 0.2710
# epoch: 4 (24%) 	running_loss: 0.2765
# epoch: 4 (27%) 	running_loss: 0.2750
# epoch: 4 (30%) 	running_loss: 0.2657
# epoch: 4 (32%) 	running_loss: 0.2856
# epoch: 4 (35%) 	running_loss: 0.2791
# epoch: 4 (38%) 	running_loss: 0.3029
# epoch: 4 (40%) 	running_loss: 0.2594
# epoch: 4 (43%) 	running_loss: 0.2826
# epoch: 4 (46%) 	running_loss: 0.2798
# epoch: 4 (49%) 	running_loss: 0.3307
# epoch: 4 (51%) 	running_loss: 0.2578
# epoch: 4 (54%) 	running_loss: 0.3343
# epoch: 4 (57%) 	running_loss: 0.2936
# epoch: 4 (59%) 	running_loss: 0.2641
# epoch: 4 (62%) 	running_loss: 0.2687
# epoch: 4 (65%) 	running_loss: 0.2657
# epoch: 4 (67%) 	running_loss: 0.2606
# epoch: 4 (70%) 	running_loss: 0.2810
# epoch: 4 (73%) 	running_loss: 0.2596
# epoch: 4 (75%) 	running_loss: 0.2814
# epoch: 4 (78%) 	running_loss: 0.2702
# epoch: 4 (81%) 	running_loss: 0.2681
# epoch: 4 (84%) 	running_loss: 0.2671
# epoch: 4 (86%) 	running_loss: 0.2770
# epoch: 4 (89%) 	running_loss: 0.2600
# epoch: 4 (92%) 	running_loss: 0.2580
# epoch: 4 (94%) 	running_loss: 0.2557
# epoch: 4 (97%) 	running_loss: 0.2706
# epoch: 4 (100%) 	running_loss: 0.2496
#
# [INFO] epoch: 4 | time_per_epoch: 88.11 sec | avg_train_loss: 0.2725 | avg_val_loss: 0.2784

# %%
# plot training and validation losses
plot.plot_losses(train_losses, val_losses, EPOCHS)

# %%
# save the model
torch.save(net.state_dict(), "checkpoints/contrastive_siamese.pth")
